# %% [markdown]
# ### Pandas: Working with DataFrames

# %%
# Set directory for the data
import pandas as pd
import numpy as np
import os
path = 'C:\\Users\\' + os.getlogin() + '\\Documents\\Programming\\Python\\MachineLearning\\Data'
os.chdir(path)
os.getcwd()
os.listdir()
# Out:
# ['01-ign.csv',
#  '02-winequality-red.csv',
#  '02-winequality-white.csv',
#  '03-thanksgiving-2015-poll-data.csv',
#  '04-ibm-sales-loss.csv']

# %%
# Get file
filename = '02-winequality-white.csv'
data = pd.read_csv(filename, delimiter=';')
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %% [markdown]
# ### Getting some basic information with functions
#
# - .info(),
# - .dtypes,
# - .describe(),
# - .head(),
# - .tail()
# - .shape
# - .index
# - .columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
# fixed acidity           4898 non-null float64
# volatile acidity        4898 non-null float64
# citric acid             4898 non-null float64
# residual sugar          4898 non-null float64
# chlorides               4898 non-null float64
# free sulfur dioxide     4898 non-null float64
# total sulfur dioxide    4898 non-null float64
# density                 4898 non-null float64
# pH                      4898 non-null float64
# sulphates               4898 non-null float64
# alcohol                 4898 non-null float64
# quality                 4898 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
data.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
# Indexing with .loc()
data.describe().loc[['min', 'max'], ['density', 'pH']]
# Out:
#      density    pH
# min  0.98711  2.72
# max  1.03898  3.82

# %%
# Get min using .iloc() so 3rd row and all columns
data.describe().iloc[3,:]
# Out:
# fixed acidity           3.80000
# volatile acidity        0.08000
# citric acid             0.00000
# residual sugar          0.60000
# chlorides               0.00900
# free sulfur dioxide     2.00000
# total sulfur dioxide    9.00000
# density                 0.98711
# pH                      2.72000
# sulphates               0.22000
# alcohol                 8.00000
# quality                 3.00000
# Name: min, dtype: float64

# %%
# Normal slicing works as well
data[0:2]
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                 45.0                 170.0    1.001  3.0       0.45
# 1                 14.0                 132.0    0.994  3.3       0.49
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6

# %% [markdown]
# #### Selecting

# %%
# Selecting a single column from the DataFrame wil return a Series object
data['fixed acidity'].head()
# Out:
# 0    7.0
# 1    6.3
# 2    8.1
# 3    7.2
# 4    7.2
# Name: fixed acidity, dtype: float64

# %%
type(data['fixed acidity'].head())
# Out:
# pandas.core.series.Series

# %%
# Selecting multiple columns by passing a list of column names to the DataFrame
print(data[['fixed acidity', 'citric acid']].head())
print('\n')

col = ['fixed acidity', 'citric acid']
print(data[col].head())
# Out:
#    fixed acidity  citric acid
# 0            7.0         0.36
# 1            6.3         0.34
# 2            8.1         0.40
# 3            7.2         0.32
# 4            7.2         0.32
#
#
#    fixed acidity  citric acid
# 0            7.0         0.36
# 1            6.3         0.34
# 2            8.1         0.40
# 3            7.2         0.32
# 4            7.2         0.32

# %%
# Row selection can be done multiple ways, but doing so by an individual index or boolean indexing are typically easiest
data[(data['fixed acidity']>10) & (data['pH']>3)].head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1239           10.3              0.25         0.48             2.2      0.042
# 1526           14.2              0.27         0.49             1.1      0.037
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1239                 28.0                 164.0    0.998  3.19       0.59
# 1526                 33.0                 156.0    0.992  3.15       0.54
#
#       alcohol  quality
# 1239      9.7        5
# 1526     11.1        6

# %%
data[(data['fixed acidity']>10) | (data['pH']>3)].head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
# 5                 30.0                  97.0   0.9951  3.26       0.44
#
#    alcohol  quality
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# ...

# %%
# Select rows by position using the iloc method
data.iloc[99]
# Out:
# fixed acidity             6.0000
# volatile acidity          0.3400
# citric acid               0.6600
# residual sugar           15.9000
# chlorides                 0.0460
# free sulfur dioxide      26.0000
# total sulfur dioxide    164.0000
# density                   0.9979
# pH                        3.1400
# sulphates                 0.5000
# alcohol                   8.8000
# quality                   6.0000
# Name: 99, dtype: float64

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
data.iloc[0]
# Out:
# fixed acidity             7.000
# volatile acidity          0.270
# citric acid               0.360
# residual sugar           20.700
# chlorides                 0.045
# free sulfur dioxide      45.000
# total sulfur dioxide    170.000
# density                   1.001
# pH                        3.000
# sulphates                 0.450
# alcohol                   8.800
# quality                   6.000
# Name: 0, dtype: float64

# %%
data.iloc[0,:]
# Out:
# fixed acidity             7.000
# volatile acidity          0.270
# citric acid               0.360
# residual sugar           20.700
# chlorides                 0.045
# free sulfur dioxide      45.000
# total sulfur dioxide    170.000
# density                   1.001
# pH                        3.000
# sulphates                 0.450
# alcohol                   8.800
# quality                   6.000
# Name: 0, dtype: float64

# %%
data.iloc[0,0:5]
# Out:
# fixed acidity        7.000
# volatile acidity     0.270
# citric acid          0.360
# residual sugar      20.700
# chlorides            0.045
# Name: 0, dtype: float64

# %%
data.iloc[0,[1,3,5]]
# Out:
# volatile acidity        0.27
# residual sugar         20.70
# free sulfur dioxide    45.00
# Name: 0, dtype: float64

# %% [markdown]
# The simplified rules of indexing are
#
# - Use loc for label-based indexing
# - Use iloc for positional indexing

# %% [markdown]
# #### Joining

# %%
left = pd.DataFrame({'key': range(5), 
                           'left_value': ['a', 'b', 'c', 'd', 'e']})
right = pd.DataFrame({'key': range(2, 7), 
                           'right_value': ['f', 'g', 'h', 'i', 'j']})
print(left)
print('\n')
print(right)
# Out:
#    key left_value
# 0    0          a
# 1    1          b
# 2    2          c
# 3    3          d
# 4    4          e
#
#
#    key right_value
# 0    2           f
# 1    3           g
# 2    4           h
# 3    5           i
# 4    6           j

# %%
# Inner join
pd.merge(left, right, on='key', how='inner')
# Out:
#    key left_value right_value
# 0    2          c           f
# 1    3          d           g
# 2    4          e           h

# %%
# Left join
pd.merge(left, right, on='key', how='left')
# Out:
#    key left_value right_value
# 0    0          a         NaN
# 1    1          b         NaN
# 2    2          c           f
# 3    3          d           g
# 4    4          e           h

# %%
# Left join
pd.merge(left, right, on='key', how='right')
# Out:
#    key left_value right_value
# 0    2          c           f
# 1    3          d           g
# 2    4          e           h
# 3    5        NaN           i
# 4    6        NaN           j

# %%
# Full outer
# Left join
pd.merge(left, right, on='key', how='outer')
# Out:
#    key left_value right_value
# 0    0          a         NaN
# 1    1          b         NaN
# 2    2          c           f
# 3    3          d           g
# 4    4          e           h
# 5    5        NaN           i
# 6    6        NaN           j

# %% [markdown]
# #### Combining

# %%
# pandas.concat takes a list of Series or DataFrames and returns a Series or DataFrame of the concatenated objects
pd.concat([left, right], sort=False)
# Out:
#    key left_value right_value
# 0    0          a         NaN
# 1    1          b         NaN
# 2    2          c         NaN
# 3    3          d         NaN
# 4    4          e         NaN
# 0    2        NaN           f
# 1    3        NaN           g
# 2    4        NaN           h
# 3    5        NaN           i
# 4    6        NaN           j

# %%
# By default, the function will vertically append the objects to one another, combining columns with the same name
# Objects can be concatentated side-by-side using the function's axis parameter
pd.concat([left, right], axis=1)
# Out:
#    key left_value  key right_value
# 0    0          a    2           f
# 1    1          b    3           g
# 2    2          c    4           h
# 3    3          d    5           i
# 4    4          e    6           j

# %% [markdown]
# #### Group by

# %%
# Get file
filename = '03-thanksgiving-2015-poll-data.csv'
data = pd.read_csv(filename)
data.head()
# Out:
#    RespondentID Do you celebrate Thanksgiving?  \
# 0    4337954960                            Yes
# 1    4337951949                            Yes
# 2    4337935621                            Yes
# 3    4337933040                            Yes
# 4    4337931983                            Yes
#
#   What is typically the main dish at your Thanksgiving dinner?  \
# 0                                             Turkey
# 1                                             Turkey
# 2                                             Turkey
# 3                                             Turkey
# 4                                           Tofurkey
#
#   What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
# Use groupby function
by_main_dish = data.groupby('What is typically the main dish at your Thanksgiving dinner?')
by_main_dish

# %%
# Calling coutn returns the total number of NOT NULL values within each column
by_main_dish.count()
# Out:
#                                                     RespondentID  \
# What is typically the main dish at your Thanksg...
# Chicken                                                       12
# Ham/Pork                                                      29
# I don't know                                                   5
# Other (please specify)                                        35
# Roast beef                                                    11
# Tofurkey                                                      20
# Turducken                                                      3
# Turkey                                                       859
#
#                                                     Do you celebrate Thanksgiving?  \
# What is typically the main dish at your Thanksg...
# Chicken                                                                         12
# Ham/Pork                                                                        29
# ...

# %%
# Get distinct titles using .nunique() then .sort_values()
by_main_dish['How is the main dish typically cooked?'].nunique().sort_values(ascending=False)
# Out:
# What is typically the main dish at your Thanksgiving dinner?
# Turkey                    5
# Other (please specify)    5
# Tofurkey                  4
# Roast beef                4
# Ham/Pork                  4
# Chicken                   4
# I don't know              3
# Turducken                 1
# Name: How is the main dish typically cooked?, dtype: int64

# %% [markdown]
# #### split-apply-combine

# %%
'''
SELECT *
FROM chicago c
INNER JOIN (
    SELECT department, max(salary) max_salary
    FROM chicago
    GROUP BY department
) m
ON c.department = m.department
AND c.salary = m.max_salary;
'''
# Out:
# '\nSELECT *\nFROM chicago c\nINNER JOIN (\n    SELECT department, max(salary) max_salary\n    FROM chicago\n    GROUP BY department\n) m\nON c.department = m.department\nAND c.salary = m.max_salary;\n'

# %%
# Define a function that will label each record from 1 to N, where N is the number of employees within a dept
# Then apply that function to each group
def ranker(df):
    '''
    Assigns a rank then DESC sort
    '''
    df['What kind of stuffing/dressing do you typically have?'] = np.arrange(len(df)) + 1
    return df

data.sort_values('What is typically the main dish at your Thanksgiving dinner?', ascending=False, inplace=True)
